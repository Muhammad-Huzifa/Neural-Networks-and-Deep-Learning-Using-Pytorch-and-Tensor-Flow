# %% [markdown]
# **To Implement the about Neural Networks**

# %%
import torch
import torch.nn as nn

# %%
class New(nn.Module):
  def __init__(self , input_features):
    super().__init__()
    self.linear_1 = nn.Linear(input_features , 3)
    self.relu = nn.ReLU()
    self.linear_2 = nn.Linear(3, 1)
    self.sigmoid = nn.Sigmoid()
  def forward(self , features):
      output = self.linear_1(features)
      output = self.relu(output)
      output = self.linear_2(output)
      output = self.sigmoid(output)
      return output

# %%
features = torch.rand(10 , 5)

# %%
features
# Out:
# tensor([[0.2540, 0.8110, 0.6261, 0.7349, 0.9890],
#         [0.3794, 0.7260, 0.8103, 0.7328, 0.8771],
#         [0.1756, 0.8188, 0.4690, 0.9784, 0.1285],
#         [0.1680, 0.6281, 0.8833, 0.1045, 0.7759],
#         [0.9978, 0.5207, 0.9495, 0.8600, 0.8763],
#         [0.2781, 0.2492, 0.3508, 0.0882, 0.4043],
#         [0.5795, 0.9721, 0.0118, 0.1242, 0.3652],
#         [0.8446, 0.9431, 0.4762, 0.8197, 0.0870],
#         [0.3375, 0.9417, 0.1581, 0.2679, 0.0893],
#         [0.1214, 0.2386, 0.7530, 0.4020, 0.6789]])

# %%
model = New(features.shape[1])

# %%
model(features)
# Out:
# tensor([[0.4904],
#         [0.4955],
#         [0.5185],
#         [0.4749],
#         [0.5134],
#         [0.5106],
#         [0.5293],
#         [0.5145],
#         [0.5252],
#         [0.4894]], grad_fn=<SigmoidBackward0>)

# %%
# !pip install torchinfo

# %%
model.linear_1.weight  , model.linear_2.weight
# Out:
# (Parameter containing:
#  tensor([[-0.4393,  0.3934,  0.3860,  0.0921,  0.1880],
#          [ 0.2897,  0.1590, -0.0803,  0.3225, -0.2576],
#          [ 0.4255, -0.1036,  0.0801,  0.1696, -0.4436]], requires_grad=True),
#  Parameter containing:
#  tensor([[-0.2323,  0.3130, -0.4974]], requires_grad=True))

# %% [markdown]
# ****Using Container****

# %%
class Model(nn.Module):
  def __init__(self , input_features):
    super().__init__()
    self.network  = nn.Sequential(
        nn.Linear(input_features , 3),
        nn.ReLU(),
        nn.Linear(3, 1),
        nn.Sigmoid()
    )
  def  forward(self , features):
    out = self.network(features)
    return out

# %%
model = Model(features.shape[1])

# %%
model(features)
# Out:
# tensor([[0.4618],
#         [0.4626],
#         [0.4685],
#         [0.4688],
#         [0.4561],
#         [0.4701],
#         [0.4597],
#         [0.4593],
#         [0.4678],
#         [0.4715]], grad_fn=<SigmoidBackward0>)
