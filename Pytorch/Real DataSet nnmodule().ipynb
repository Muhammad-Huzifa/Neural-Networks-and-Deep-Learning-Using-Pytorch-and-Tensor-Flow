# %%
import torch
import torch.nn as nn
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('https://raw.githubusercontent.com/gscdit/Breast-Cancer-Detection/refs/heads/master/data.csv')
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
 df.drop(columns=['Unnamed: 32','id'],inplace=True)

# %%
X_train,X_test,y_train,y_test = train_test_split(df.drop(columns=['diagnosis']),df['diagnosis'],test_size=0.2,random_state=42)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
encoder = LabelEncoder()
y_train = encoder.fit_transform(y_train)
y_test = encoder.transform(y_test)

# %%
X_train = torch.tensor(X_train,dtype=torch.float32)
X_test = torch.tensor(X_test,dtype=torch.float32)
y_train = torch.tensor(y_train,dtype=torch.float32)
y_test = torch.tensor(y_test,dtype=torch.float32)

# %%
class SimlpeNet(nn.Module):
    def __init__(self , input_features):
        super().__init__()
        self.network = nn.Sequential(
            nn.Linear(input_features,1),
            nn.Sigmoid()
             )
    def forward(self , features):
      out = self.network(features)
      return out

# %% [markdown]
# **Loss Function**

# %%
loss_function = nn.BCELoss()

# %% [markdown]
# **Optimizer**

# %%
optimizer = torch.optim.SGD(model.parameters(),lr=0.01)

# %%
model = SimlpeNet(X_train.shape[1])

# %%
epochs = 50

# %%
for epoch in range(epochs):
  y_pred = model(X_train)
  loss = loss_function(y_pred,y_train.view(-1,1))
  optimizer.zero_grad()

  loss.backward()

  optimizer.step()
  print(f'Epoch : {epoch} , Loss : {loss.item()}')
# Out:
# Epoch : 0 , Loss : 0.6860328912734985
# Epoch : 1 , Loss : 0.6860328912734985
# Epoch : 2 , Loss : 0.6860328912734985
# Epoch : 3 , Loss : 0.6860328912734985
# Epoch : 4 , Loss : 0.6860328912734985
# Epoch : 5 , Loss : 0.6860328912734985
# Epoch : 6 , Loss : 0.6860328912734985
# Epoch : 7 , Loss : 0.6860328912734985
# Epoch : 8 , Loss : 0.6860328912734985
# Epoch : 9 , Loss : 0.6860328912734985
# Epoch : 10 , Loss : 0.6860328912734985
# Epoch : 11 , Loss : 0.6860328912734985
# Epoch : 12 , Loss : 0.6860328912734985
# Epoch : 13 , Loss : 0.6860328912734985
# Epoch : 14 , Loss : 0.6860328912734985
# Epoch : 15 , Loss : 0.6860328912734985
# Epoch : 16 , Loss : 0.6860328912734985
# Epoch : 17 , Loss : 0.6860328912734985
# Epoch : 18 , Loss : 0.6860328912734985
# Epoch : 19 , Loss : 0.6860328912734985
# Epoch : 20 , Loss : 0.6860328912734985
# Epoch : 21 , Loss : 0.6860328912734985
# Epoch : 22 , Loss : 0.6860328912734985
# Epoch : 23 , Loss : 0.6860328912734985
# Epoch : 24 , Loss : 0.6860328912734985
# Epoch : 25 , Loss : 0.6860328912734985
# Epoch : 26 , Loss : 0.6860328912734985
# Epoch : 27 , Loss : 0.6860328912734985
# Epoch : 28 , Loss : 0.6860328912734985
# Epoch : 29 , Loss : 0.6860328912734985
# Epoch : 30 , Loss : 0.6860328912734985
# Epoch : 31 , Loss : 0.6860328912734985
# Epoch : 32 , Loss : 0.6860328912734985
# Epoch : 33 , Loss : 0.6860328912734985
# Epoch : 34 , Loss : 0.6860328912734985
# Epoch : 35 , Loss : 0.6860328912734985
# Epoch : 36 , Loss : 0.6860328912734985
# Epoch : 37 , Loss : 0.6860328912734985
# Epoch : 38 , Loss : 0.6860328912734985
# Epoch : 39 , Loss : 0.6860328912734985
# Epoch : 40 , Loss : 0.6860328912734985
# Epoch : 41 , Loss : 0.6860328912734985
# Epoch : 42 , Loss : 0.6860328912734985
# Epoch : 43 , Loss : 0.6860328912734985
# Epoch : 44 , Loss : 0.6860328912734985
# Epoch : 45 , Loss : 0.6860328912734985
# Epoch : 46 , Loss : 0.6860328912734985
# Epoch : 47 , Loss : 0.6860328912734985
# Epoch : 48 , Loss : 0.6860328912734985
# Epoch : 49 , Loss : 0.6860328912734985

# %%
accuracy= accuracy_score(y_test,y_pred.round())
print(f'Accuracy : {accuracy}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3081ce7c067c> in <cell line: 0>()
# ----> 1 accuracy= accuracy_score(y_test,y_pred.round())
#       2 print(f'Accuracy : {accuracy}')
#
# NameError: name 'accuracy_score' is not defined

# %%
prediction = model.forward(X_test[1:10])
prediction
# Out:
# tensor([[0.4727],
#         [0.5893],
#         [0.3985],
#         [0.4008],
#         [0.6103],
#         [0.3436],
#         [0.3411],
#         [0.5172],
#         [0.4846]], grad_fn=<SigmoidBackward0>)

# %%
y_test[1:10]
# Out:
# tensor([1., 1., 0., 0., 1., 1., 1., 0., 0.])
